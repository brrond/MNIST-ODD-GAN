# %%
# Imports
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import tensorflow as tf
import seaborn as sb
import pandas as pd
import numpy as np

# %%
# check that gpu is available:
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Load MNIST Dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
assert x_train.shape == (60000, 28, 28)
assert x_test.shape == (10000, 28, 28)
assert y_train.shape == (60000,)
assert y_test.shape == (10000,)

# %%
# examine dataset
print(x_train.min(), x_train.max(), x_train.dtype, x_train.shape)
print(y_train.min(), y_train.max(), y_train.dtype, y_train.shape)
# Out:
# 0 255 uint8 (60000, 28, 28)
# 0 9 uint8 (60000,)

# %%
# normalize images
x_train = x_train / 255.
x_test = x_test / 255.
x_train.shape += (1,)
x_test.shape += (1,)

# %%
# use only small part of the dataset (~50 images pro class)
# it's actually 500 images in total
_, x_train, _, y_train = train_test_split(x_train, y_train, test_size=50*10, shuffle=True, random_state=42)

# %%
# examine normalized dataset
print(x_train.min(), x_train.max(), x_train.dtype, x_train.shape)
print(y_train.min(), y_train.max(), y_train.dtype, y_train.shape)
# Out:
# 0.0 1.0 float64 (500, 28, 28, 1)
# 0 9 uint8 (500,)

# %%
# Visualize some numbers
plt.figure(figsize=(10, 10))
plt.title("MNIST Dataset", pad=20)
plt.axis(False)

for i in range(0, 5):
    for j in range(0, 5):

        idx = i * 5 + j + 1
        plt.subplot(5, 5, idx)
        plt.imshow(x_train[idx], cmap="gray")
        plt.title(y_train[idx])
        plt.axis(False)

# %%
# inspect class distributions
df = pd.DataFrame(y_train)
sb.displot(df, legend=False)
del df

# %%
# some basic GAN

## discriminator
disc = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(28, 28, 1)),
    tf.keras.layers.Conv2D(32, 5, strides=2, padding="same", activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Conv2D(64, 5, strides=2, padding="same", activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Conv2D(128, 5, strides=2, padding="same", activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

## Generator
gen = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(128,)),
    tf.keras.layers.Dense(7*7*256, use_bias=False),
    tf.keras.layers.Reshape((7, 7, 256)),
    tf.keras.layers.Conv2DTranspose(128, 5, strides=1, padding="same", use_bias=False),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.LeakyReLU(),
    tf.keras.layers.Conv2DTranspose(256, 5, strides=2, padding="same", use_bias=False),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.LeakyReLU(),
    tf.keras.layers.Conv2DTranspose(1, 5, strides=2, padding="same", activation="sigmoid", use_bias=False),
])

gen.output_shape
# Out:
# (None, 28, 28, 1)

# %%
rand = tf.random.normal((16, 128, 1))
out = gen(rand, training=False)

plt.imshow(out[0], cmap="gray")
plt.axis(False)

out = out.numpy()
print(out.min(), out.max(), out.dtype, out.shape)
del out, rand
# Out:
# 0.47974885 0.5198663 float32 (16, 28, 28, 1)

# %%
## losses
bc = tf.keras.losses.BinaryCrossentropy()
def discriminator_loss(real, fake):
    real_loss = bc(tf.ones_like(real), real)
    fake_loss = bc(tf.zeros_like(fake), fake)
    return real_loss + fake_loss

def generator_loss(fake):
    return bc(tf.ones_like(fake), fake)

# %%
## combined model
class GAN(tf.keras.Model):
    def __init__(self, gen, disc):
        super().__init__()

        self.gen = gen
        self.disc = disc

    def compile(self, g_optimizer, d_optimizer, gen_loss, disc_loss):
        super().compile()
        self.g_optimizer = g_optimizer
        self.d_optimizer = d_optimizer
        self.gen_loss = gen_loss
        self.disc_loss = disc_loss

    def train_step(self, real_images):
        shape = tf.shape(real_images)
        rand = tf.random.normal((shape[0], 128, 1))

        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            fake_images = self.gen(rand, training=True)

            out = self.disc(real_images, training=True)
            fake_out = self.disc(fake_images, training=True)

            g_loss = self.gen_loss(fake_out)
            d_loss = self.disc_loss(out, fake_out)

        gen_grads = gen_tape.gradient(g_loss, self.gen.trainable_weights)
        disc_grads = disc_tape.gradient(d_loss, self.disc.trainable_weights)
        self.d_optimizer.apply_gradients(zip(disc_grads, self.disc.trainable_weights))
        self.g_optimizer.apply_gradients(zip(gen_grads, self.gen.trainable_weights))

        return {"d_loss": d_loss, "g_loss": g_loss}

# %%
gan = GAN(gen, disc)

gan.compile(
    tf.keras.optimizers.Adam(1e-4),
    tf.keras.optimizers.Adam(1e-4),
    generator_loss,
    discriminator_loss
)

# %%
# define callbacks
def draw_random():
    # Visualize results
    rand = tf.random.normal((25, 128, 1))
    out = gen(rand, training=False)

    fig = plt.figure(figsize=(10, 10))
    canvas = fig.canvas
    for i in range(5):
        for j in range(5):
            idx = i * 5 + j
            plt.subplot(5, 5, idx + 1)
            plt.axis(False)
            plt.imshow(out[idx], cmap="gray")

    plt.tight_layout()
    canvas.draw()
    return canvas

def visualize(epoch, filew):
    canvas = draw_random()
    image_flat = np.frombuffer(canvas.tostring_rgb(), dtype='uint8')
    image = image_flat.reshape(*reversed(canvas.get_width_height()), 3)
    plt.close()
    with filew.as_default():
        tf.summary.image("Generation Results", image.reshape((1,) + image.shape), epoch)

logdir = "mnist-gan/logs/"
file_writer = tf.summary.create_file_writer(logdir + "images/")
write_images_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=lambda epoch, logs: visualize(epoch, file_writer))

callbacks = [
    tf.keras.callbacks.CSVLogger("mnist-gan/mnist-gan.csv"),
    tf.keras.callbacks.TerminateOnNaN(),
    tf.keras.callbacks.TensorBoard(logdir),
    write_images_callback,
]

# %%
history = gan.fit(x_train, batch_size=32, epochs=200, callbacks=callbacks)
# Out:
# Epoch 1/200
# 16/16 [==============================] - 3s 50ms/step - d_loss: 0.6024 - g_loss: 2.7414
# Epoch 2/200
#  3/16 [====>.........................] - ETA: 0s - d_loss: 0.0703 - g_loss: 4.2400
# C:\Users\danya\AppData\Local\Temp\ipykernel_24904\2707781873.py:22: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed in 3.10. Use buffer_rgba instead.
#   image_flat = np.frombuffer(canvas.tostring_rgb(), dtype='uint8')
# 16/16 [==============================] - 1s 69ms/step - d_loss: 0.0804 - g_loss: 4.1427
# Epoch 3/200
# 16/16 [==============================] - 1s 61ms/step - d_loss: 0.1069 - g_loss: 3.8204
# Epoch 4/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.0569 - g_loss: 4.7436
# Epoch 5/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.1072 - g_loss: 4.4670
# Epoch 6/200
# 16/16 [==============================] - 1s 52ms/step - d_loss: 0.0912 - g_loss: 4.5923
# Epoch 7/200
# 16/16 [==============================] - 1s 72ms/step - d_loss: 0.0849 - g_loss: 4.7218
# Epoch 8/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.1448 - g_loss: 4.4226
# Epoch 9/200
# 16/16 [==============================] - 1s 60ms/step - d_loss: 0.0970 - g_loss: 5.1300
# Epoch 10/200
# 16/16 [==============================] - 1s 53ms/step - d_loss: 0.1069 - g_loss: 4.7524
# Epoch 11/200
# 16/16 [==============================] - 1s 61ms/step - d_loss: 0.1226 - g_loss: 4.8224
# Epoch 12/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.1534 - g_loss: 4.5591
# Epoch 13/200
# 16/16 [==============================] - 1s 52ms/step - d_loss: 0.1332 - g_loss: 4.7857
# Epoch 14/200
# 16/16 [==============================] - 1s 78ms/step - d_loss: 0.1162 - g_loss: 4.5802
# Epoch 15/200
# 16/16 [==============================] - 1s 53ms/step - d_loss: 0.1114 - g_loss: 4.8963
# Epoch 16/200
# 16/16 [==============================] - 1s 51ms/step - d_loss: 0.1159 - g_loss: 5.0383
# Epoch 17/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.1883 - g_loss: 4.6703
# Epoch 18/200
# 16/16 [==============================] - 1s 59ms/step - d_loss: 0.2404 - g_loss: 4.3911
# Epoch 19/200
# 16/16 [==============================] - 1s 57ms/step - d_loss: 0.6475 - g_loss: 2.8469
# Epoch 20/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.5059 - g_loss: 3.3102
# Epoch 21/200
# 16/16 [==============================] - 1s 53ms/step - d_loss: 0.5699 - g_loss: 2.8814
# Epoch 22/200
# 16/16 [==============================] - 1s 82ms/step - d_loss: 0.4951 - g_loss: 3.2823
# Epoch 23/200
# 16/16 [==============================] - 1s 53ms/step - d_loss: 0.9904 - g_loss: 2.5552
# Epoch 24/200
# 16/16 [==============================] - 1s 53ms/step - d_loss: 0.8738 - g_loss: 2.6254
# Epoch 25/200
# 16/16 [==============================] - 1s 53ms/step - d_loss: 0.5214 - g_loss: 2.9396
# Epoch 26/200
# 16/16 [==============================] - 1s 52ms/step - d_loss: 0.5375 - g_loss: 3.1116
# Epoch 27/200
# 16/16 [==============================] - 1s 53ms/step - d_loss: 0.7659 - g_loss: 2.8269
# Epoch 28/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.8540 - g_loss: 2.4505
# Epoch 29/200
# 16/16 [==============================] - 1s 52ms/step - d_loss: 0.7230 - g_loss: 2.6242
# Epoch 30/200
# 16/16 [==============================] - 1s 59ms/step - d_loss: 0.6366 - g_loss: 2.8470
# Epoch 31/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.7322 - g_loss: 2.5105
# Epoch 32/200
# 16/16 [==============================] - 1s 59ms/step - d_loss: 0.7637 - g_loss: 2.4324
# Epoch 33/200
# 16/16 [==============================] - 2s 102ms/step - d_loss: 0.5799 - g_loss: 2.8985
# Epoch 34/200
# 16/16 [==============================] - 1s 61ms/step - d_loss: 0.6720 - g_loss: 2.7284
# Epoch 35/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.9509 - g_loss: 2.2067
# Epoch 36/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 1.0718 - g_loss: 2.1044
# Epoch 37/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.7265 - g_loss: 2.6086
# Epoch 38/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.6179 - g_loss: 2.7612
# Epoch 39/200
# 16/16 [==============================] - 1s 60ms/step - d_loss: 0.6579 - g_loss: 2.6973
# Epoch 40/200
# 16/16 [==============================] - 1s 58ms/step - d_loss: 0.8450 - g_loss: 2.2774
# Epoch 41/200
# 16/16 [==============================] - 1s 59ms/step - d_loss: 0.9252 - g_loss: 2.1396
# Epoch 42/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.7322 - g_loss: 2.5913
# Epoch 43/200
# 16/16 [==============================] - 1s 66ms/step - d_loss: 0.5525 - g_loss: 2.8208
# Epoch 44/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.6412 - g_loss: 2.8226
# Epoch 45/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.6916 - g_loss: 2.5760
# Epoch 46/200
# 16/16 [==============================] - 1s 95ms/step - d_loss: 0.6654 - g_loss: 2.6309
# Epoch 47/200
# 16/16 [==============================] - 1s 57ms/step - d_loss: 0.6578 - g_loss: 2.5060
# Epoch 48/200
# 16/16 [==============================] - 1s 66ms/step - d_loss: 0.7225 - g_loss: 2.4644
# Epoch 49/200
# 16/16 [==============================] - 1s 57ms/step - d_loss: 0.7517 - g_loss: 2.4408
# Epoch 50/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.6458 - g_loss: 2.4784
# Epoch 51/200
# 16/16 [==============================] - 1s 58ms/step - d_loss: 0.6281 - g_loss: 2.6972
# Epoch 52/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.5515 - g_loss: 2.7301
# Epoch 53/200
# 16/16 [==============================] - 1s 59ms/step - d_loss: 0.5818 - g_loss: 2.5070
# Epoch 54/200
# 16/16 [==============================] - 1s 57ms/step - d_loss: 0.7225 - g_loss: 2.4079
# Epoch 55/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.7217 - g_loss: 2.5046
# Epoch 56/200
# 16/16 [==============================] - 1s 53ms/step - d_loss: 0.5105 - g_loss: 3.0062
# Epoch 57/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.5531 - g_loss: 2.6874
# Epoch 58/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.5393 - g_loss: 2.8117
# Epoch 59/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.5539 - g_loss: 2.8111
# Epoch 60/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.6091 - g_loss: 2.6663
# Epoch 61/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.5324 - g_loss: 2.8061
# Epoch 62/200
# 16/16 [==============================] - 2s 114ms/step - d_loss: 0.4910 - g_loss: 2.7101
# Epoch 63/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.4809 - g_loss: 3.0628
# Epoch 64/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.4847 - g_loss: 2.9622
# Epoch 65/200
# 16/16 [==============================] - 1s 60ms/step - d_loss: 0.4674 - g_loss: 2.9442
# Epoch 66/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.6234 - g_loss: 2.7267
# Epoch 67/200
# 16/16 [==============================] - 1s 60ms/step - d_loss: 0.5713 - g_loss: 2.7430
# Epoch 68/200
# 16/16 [==============================] - 1s 59ms/step - d_loss: 0.5133 - g_loss: 2.9443
# Epoch 69/200
# 16/16 [==============================] - 1s 60ms/step - d_loss: 0.4652 - g_loss: 3.0996
# Epoch 70/200
# 16/16 [==============================] - 1s 58ms/step - d_loss: 0.4867 - g_loss: 2.9641
# Epoch 71/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.4659 - g_loss: 2.9364
# Epoch 72/200
# 16/16 [==============================] - 1s 60ms/step - d_loss: 0.4942 - g_loss: 2.8515
# Epoch 73/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.5232 - g_loss: 3.1171
# Epoch 74/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.5434 - g_loss: 2.9631
# Epoch 75/200
# 16/16 [==============================] - 1s 57ms/step - d_loss: 0.4553 - g_loss: 3.1911
# Epoch 76/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.5217 - g_loss: 3.0420
# Epoch 77/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.4606 - g_loss: 3.1059
# Epoch 78/200
# 16/16 [==============================] - 1s 57ms/step - d_loss: 0.4655 - g_loss: 3.0630
# Epoch 79/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.5234 - g_loss: 2.9381
# Epoch 80/200
# 16/16 [==============================] - 1s 58ms/step - d_loss: 0.5119 - g_loss: 2.9227
# Epoch 81/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.4359 - g_loss: 3.0710
# Epoch 82/200
# 16/16 [==============================] - 2s 119ms/step - d_loss: 0.4035 - g_loss: 3.3570
# Epoch 83/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.4190 - g_loss: 3.2109
# Epoch 84/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.4186 - g_loss: 3.1339
# Epoch 85/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.4416 - g_loss: 3.2550
# Epoch 86/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.4655 - g_loss: 3.2612
# Epoch 87/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.3570 - g_loss: 3.3454
# Epoch 88/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.3876 - g_loss: 3.1593
# Epoch 89/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.4097 - g_loss: 3.3004
# Epoch 90/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.4816 - g_loss: 3.1167
# Epoch 91/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.4635 - g_loss: 3.3742
# Epoch 92/200
# 16/16 [==============================] - 1s 57ms/step - d_loss: 0.4293 - g_loss: 3.1582
# Epoch 93/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.3916 - g_loss: 3.4127
# Epoch 94/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.3925 - g_loss: 3.3497
# Epoch 95/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.4232 - g_loss: 3.3338
# Epoch 96/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.3868 - g_loss: 3.2045
# Epoch 97/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.3837 - g_loss: 3.4535
# Epoch 98/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.4100 - g_loss: 3.2743
# Epoch 99/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.3835 - g_loss: 3.3995
# Epoch 100/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.3338 - g_loss: 3.4175
# Epoch 101/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.4235 - g_loss: 3.4336
# Epoch 102/200
# 16/16 [==============================] - 1s 58ms/step - d_loss: 0.3845 - g_loss: 3.3691
# Epoch 103/200
# 16/16 [==============================] - 1s 61ms/step - d_loss: 0.4082 - g_loss: 3.4610
# Epoch 104/200
# 16/16 [==============================] - 1s 63ms/step - d_loss: 0.4317 - g_loss: 3.3067
# Epoch 105/200
# 16/16 [==============================] - 1s 60ms/step - d_loss: 0.4428 - g_loss: 3.5043
# Epoch 106/200
# 16/16 [==============================] - 1s 60ms/step - d_loss: 0.4054 - g_loss: 3.6733
# Epoch 107/200
# 16/16 [==============================] - 2s 133ms/step - d_loss: 0.4471 - g_loss: 3.5830
# Epoch 108/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.4782 - g_loss: 3.1911
# Epoch 109/200
# 16/16 [==============================] - 1s 63ms/step - d_loss: 0.3542 - g_loss: 3.5295
# Epoch 110/200
# 16/16 [==============================] - 1s 64ms/step - d_loss: 0.4041 - g_loss: 3.1200
# Epoch 111/200
# 16/16 [==============================] - 1s 57ms/step - d_loss: 0.4616 - g_loss: 3.2797
# Epoch 112/200
# 16/16 [==============================] - 1s 58ms/step - d_loss: 0.3672 - g_loss: 3.5190
# Epoch 113/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.4203 - g_loss: 3.4831
# Epoch 114/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.3344 - g_loss: 3.5352
# Epoch 115/200
# 16/16 [==============================] - 1s 53ms/step - d_loss: 0.4245 - g_loss: 3.3148
# Epoch 116/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.4544 - g_loss: 3.2973
# Epoch 117/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.4176 - g_loss: 3.3707
# Epoch 118/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.4169 - g_loss: 3.3623
# Epoch 119/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.4273 - g_loss: 3.3867
# Epoch 120/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.3757 - g_loss: 3.5251
# Epoch 121/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.3753 - g_loss: 3.4966
# Epoch 122/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.4312 - g_loss: 3.5544
# Epoch 123/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.4364 - g_loss: 3.5085
# Epoch 124/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.4428 - g_loss: 3.3721
# Epoch 125/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.4817 - g_loss: 3.3740
# Epoch 126/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.3939 - g_loss: 3.3672
# Epoch 127/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.3474 - g_loss: 3.6177
# Epoch 128/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.3970 - g_loss: 3.4366
# Epoch 129/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.4134 - g_loss: 3.5172
# Epoch 130/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.4299 - g_loss: 3.4253
# Epoch 131/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.4156 - g_loss: 3.3218
# Epoch 132/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.3529 - g_loss: 3.5456
# Epoch 133/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.4541 - g_loss: 3.6370
# Epoch 134/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.4360 - g_loss: 3.3895
# Epoch 135/200
# 16/16 [==============================] - 1s 59ms/step - d_loss: 0.3798 - g_loss: 3.3997
# Epoch 136/200
# 16/16 [==============================] - 1s 60ms/step - d_loss: 0.3448 - g_loss: 3.4884
# Epoch 137/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.4022 - g_loss: 3.4706
# Epoch 138/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.4185 - g_loss: 3.4338
# Epoch 139/200
# 16/16 [==============================] - 3s 166ms/step - d_loss: 0.4134 - g_loss: 3.3874
# Epoch 140/200
# 16/16 [==============================] - 1s 66ms/step - d_loss: 0.4288 - g_loss: 3.4117
# Epoch 141/200
# 16/16 [==============================] - 1s 60ms/step - d_loss: 0.4326 - g_loss: 3.5300
# Epoch 142/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.4611 - g_loss: 3.3977
# Epoch 143/200
# 16/16 [==============================] - 1s 60ms/step - d_loss: 0.3426 - g_loss: 3.6814
# Epoch 144/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.4086 - g_loss: 3.5399
# Epoch 145/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.4020 - g_loss: 3.6506
# Epoch 146/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.3705 - g_loss: 3.3312
# Epoch 147/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.3857 - g_loss: 3.6161
# Epoch 148/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.3558 - g_loss: 3.4319
# Epoch 149/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.3883 - g_loss: 3.4328
# Epoch 150/200
# 16/16 [==============================] - 1s 59ms/step - d_loss: 0.3912 - g_loss: 3.7835
# Epoch 151/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.4115 - g_loss: 3.3238
# Epoch 152/200
# 16/16 [==============================] - 1s 57ms/step - d_loss: 0.3965 - g_loss: 3.4754
# Epoch 153/200
# 16/16 [==============================] - 1s 60ms/step - d_loss: 0.3266 - g_loss: 3.7053
# Epoch 154/200
# 16/16 [==============================] - 1s 62ms/step - d_loss: 0.3498 - g_loss: 3.5109
# Epoch 155/200
# 16/16 [==============================] - 1s 61ms/step - d_loss: 0.3486 - g_loss: 3.6854
# Epoch 156/200
# 16/16 [==============================] - 1s 62ms/step - d_loss: 0.3614 - g_loss: 3.8508
# Epoch 157/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.4066 - g_loss: 3.4903
# Epoch 158/200
# 16/16 [==============================] - 1s 57ms/step - d_loss: 0.3468 - g_loss: 3.5669
# Epoch 159/200
# 16/16 [==============================] - 1s 57ms/step - d_loss: 0.4004 - g_loss: 3.5951
# Epoch 160/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.3663 - g_loss: 3.6669
# Epoch 161/200
# 16/16 [==============================] - 1s 57ms/step - d_loss: 0.3857 - g_loss: 3.7059
# Epoch 162/200
# 16/16 [==============================] - 1s 58ms/step - d_loss: 0.3343 - g_loss: 3.9774
# Epoch 163/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.4109 - g_loss: 3.7220
# Epoch 164/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.4036 - g_loss: 3.5502
# Epoch 165/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.3159 - g_loss: 3.8134
# Epoch 166/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.3583 - g_loss: 3.6260
# Epoch 167/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.3181 - g_loss: 3.5479
# Epoch 168/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.3786 - g_loss: 3.5381
# Epoch 169/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.3054 - g_loss: 3.6647
# Epoch 170/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.2774 - g_loss: 3.8656
# Epoch 171/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.2883 - g_loss: 3.8986
# Epoch 172/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.3438 - g_loss: 3.6687
# Epoch 173/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.3701 - g_loss: 3.7878
# Epoch 174/200
# 16/16 [==============================] - 1s 60ms/step - d_loss: 0.3857 - g_loss: 3.5450
# Epoch 175/200
# 16/16 [==============================] - 1s 57ms/step - d_loss: 0.3422 - g_loss: 3.9595
# Epoch 176/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.3165 - g_loss: 4.0310
# Epoch 177/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.2907 - g_loss: 3.6525
# Epoch 178/200
# 16/16 [==============================] - 3s 171ms/step - d_loss: 0.3805 - g_loss: 3.7831
# Epoch 179/200
# 16/16 [==============================] - 1s 63ms/step - d_loss: 0.3049 - g_loss: 3.9250
# Epoch 180/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.3531 - g_loss: 3.6848
# Epoch 181/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.3960 - g_loss: 3.6436
# Epoch 182/200
# 16/16 [==============================] - 1s 54ms/step - d_loss: 0.2992 - g_loss: 3.9727
# Epoch 183/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.2951 - g_loss: 3.8661
# Epoch 184/200
# 16/16 [==============================] - 1s 58ms/step - d_loss: 0.2962 - g_loss: 4.0298
# Epoch 185/200
# 16/16 [==============================] - 1s 55ms/step - d_loss: 0.3843 - g_loss: 3.6991
# Epoch 186/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.2633 - g_loss: 4.1499
# Epoch 187/200
# 16/16 [==============================] - 1s 65ms/step - d_loss: 0.2883 - g_loss: 3.8816
# Epoch 188/200
# 16/16 [==============================] - 1s 66ms/step - d_loss: 0.3058 - g_loss: 3.9340
# Epoch 189/200
# 16/16 [==============================] - 1s 63ms/step - d_loss: 0.3130 - g_loss: 3.9506
# Epoch 190/200
# 16/16 [==============================] - 1s 67ms/step - d_loss: 0.2905 - g_loss: 3.9932
# Epoch 191/200
# 16/16 [==============================] - 1s 61ms/step - d_loss: 0.2321 - g_loss: 4.1810
# Epoch 192/200
# 16/16 [==============================] - 1s 61ms/step - d_loss: 0.3278 - g_loss: 3.8070
# Epoch 193/200
# 16/16 [==============================] - 1s 63ms/step - d_loss: 0.3126 - g_loss: 3.8857
# Epoch 194/200
# 16/16 [==============================] - 1s 60ms/step - d_loss: 0.2740 - g_loss: 4.1154
# Epoch 195/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.2584 - g_loss: 4.1692
# Epoch 196/200
# 16/16 [==============================] - 1s 56ms/step - d_loss: 0.3240 - g_loss: 3.8637
# Epoch 197/200
# 16/16 [==============================] - 1s 59ms/step - d_loss: 0.3037 - g_loss: 4.0004
# Epoch 198/200
# 16/16 [==============================] - 1s 64ms/step - d_loss: 0.2947 - g_loss: 3.8789
# Epoch 199/200
# 16/16 [==============================] - 1s 66ms/step - d_loss: 0.2480 - g_loss: 4.0180
# Epoch 200/200
# 16/16 [==============================] - 1s 57ms/step - d_loss: 0.2902 - g_loss: 4.0046

# %%
## Visualize training process
fig = plt.figure()
canvas = fig.canvas
plt.title("Training loss")
plt.plot(list(range(1, 201)), history.history["d_loss"])
plt.plot(list(range(1, 201)), history.history["g_loss"])
plt.xlim(1, 200)
plt.grid()
plt.legend(["Discriminator Loss", "Generator Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
canvas.draw()

image_flat = np.frombuffer(canvas.tostring_rgb(), dtype='uint8')
image = image_flat.reshape(*reversed(canvas.get_width_height()), 3)
with file_writer.as_default():
        tf.summary.image("Training losses", image.reshape((1,) + image.shape), 1)
# Out:
# C:\Users\danya\AppData\Local\Temp\ipykernel_24904\4186012342.py:14: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed in 3.10. Use buffer_rgba instead.
#   image_flat = np.frombuffer(canvas.tostring_rgb(), dtype='uint8')

# %% [markdown]
# to start tensorboard:
# ```
# tensorboard --samples_per_plugin images=100 --logdir mnist-gan/logs
# ```

# %%
draw_random()

# %%
# save models
gen.save("mnist-gan/gen.keras")
disc.save("mnist-gan/disc.keras")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
